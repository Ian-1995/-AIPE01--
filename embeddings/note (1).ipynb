# %% [markdown]
# ## 1140722
#
# ---
#
# ## 📊 cosine\_similarity vs rerank-multilingual-v3.0 比較表
#
# | 項目        | `cosine_similarity` | `rerank-multilingual-v3.0` |
# | --------- | ------------------- | -------------------------- |
# | **模型類型**  | 向量相似度（embedding）    | Transformer-based reranker |
# | **計算方式**  | 比較向量角度              | 利用模型逐對語句評分                 |
# | **語意理解**  | 弱（只看向量）             | 強（上下文、語法）                  |
# | **多語言支援** | 取決於 embedding 模型    | ✅ 原生支援多語言                  |
# | **精確度**   | 中等（依嵌入品質）           | 高（語境理解強）                   |
# | **執行效率**  | 高速（可批次計算）           | 較慢（需多次 forward pass）       |
# | **適用場景**  | 初步檢索、語意比對           | 精準排序、QA、推薦                 |
#
# ---
#
# ## 🔧 常見應用場景組合建議
#
# 若你正在建立語意搜尋或課程推薦系統，常見的最佳組合為：
#
# * 🔍 **初步檢索階段**：使用 `embedding + cosine_similarity` 找出 Top-N 候選項目
# * 🧠 **重排階段**：使用 `rerank-multilingual-v3.0` 對 Top-N 做更精準排序（尤其適用於多語言情境）
#
# ---

# %% [markdown]
# ![image.png](attachment:image.png)
