# %%
import pandas as pd
from pprint import pprint as pp
import ast
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

job_df = pd.read_csv(
    r"C:\Users\student\期末專題\embeddings\104_skills_embedding_1140721.csv"
)
course_df = pd.read_csv(
    r"C:\Users\student\期末專題\embeddings\coursera_skills_embedding_1140721.csv"
)

job_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 86 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   job_id    5 non-null      object
#  1   更新日期      5 non-null      object
#  2   查詢職類      5 non-null      int64
#  3   查詢關鍵字     5 non-null      object
#  4   職務類別      5 non-null      object
#  5   職缺名稱      5 non-null      object
#  6   公司名稱      5 non-null      object
#  7   公司連結      5 non-null      object
#  8   產業別       5 non-null      object
#  9   上班地點      5 non-null      object
#  10  地區        5 non-null      object
#  11  城市        5 non-null      object
#  12  國家        5 non-null      object
#  13  薪資        5 non-null      object
#  14  薪資下限      5 non-null      int64
#  15  薪資上限      5 non-null      int64
#  16  職缺描述      5 non-null      object
#  17  職務需求      0 non-null      float64
#  18  工作經歷要求    5 non-null      object
#  19  學歷要求      5 non-null      object
#  20  科系要求      1 non-null      object
#  21  擅長工具      4 non-null      object
#  22  中文聽力      0 non-null      float64
#  23  中文口說      0 non-null      float64
#  24  中文閱讀      0 non-null      float64
#  25  中文寫作      0 non-null      float64
#  26  英文聽力      1 non-null      object
#  27  英文口說      1 non-null      object
#  28  英文閱讀      1 non-null      object
#  29  英文寫作      1 non-null      object
#  30  日文聽力      0 non-null      float64
#  31  日文口說      0 non-null      float64
#  32  日文閱讀      0 non-null      float64
#  33  日文寫作      0 non-null      float64
#  34  台語聽力      0 non-null      float64
#  35  台語口說      0 non-null      float64
#  36  台語閱讀      0 non-null      float64
#  37  台語寫作      0 non-null      float64
#  38  其他條件      1 non-null      object
#  39  福利制度      4 non-null      object
#  40  法定福利      3 non-null      object
#  41  其他福利      5 non-null      object
#  42  面試流程      0 non-null      float64
#  43  職缺連結      5 non-null      object
#  44  爬取時間      5 non-null      object
#  45  技能1       5 non-null      object
#  46  技能2       5 non-null      object
#  47  技能3       5 non-null      object
#  48  技能4       5 non-null      object
#  49  技能5       5 non-null      object
#  50  技能6       5 non-null      object
#  51  技能7       5 non-null      object
#  52  技能8       5 non-null      object
#  53  技能9       5 non-null      object
#  54  技能10      5 non-null      object
#  55  技能11      3 non-null      object
#  56  技能12      3 non-null      object
#  57  技能13      2 non-null      object
#  58  技能14      2 non-null      object
#  59  技能15      1 non-null      object
#  60  技能16      1 non-null      object
#  61  技能17      1 non-null      object
#  62  技能18      1 non-null      object
#  63  技能19      1 non-null      object
#  64  技能20      1 non-null      object
#  65  技能1向量     5 non-null      object
#  66  技能2向量     5 non-null      object
#  67  技能3向量     5 non-null      object
#  68  技能4向量     5 non-null      object
#  69  技能5向量     5 non-null      object
#  70  技能6向量     5 non-null      object
#  71  技能7向量     5 non-null      object
#  72  技能8向量     5 non-null      object
#  73  技能9向量     5 non-null      object
#  74  技能10向量    5 non-null      object
#  75  技能11向量    3 non-null      object
#  76  技能12向量    3 non-null      object
#  77  技能13向量    2 non-null      object
#  78  技能14向量    2 non-null      object
#  79  技能15向量    1 non-null      object
#  80  技能16向量    1 non-null      object
#  81  技能17向量    1 non-null      object
#  82  技能18向量    1 non-null      object
#  83  技能19向量    1 non-null      object
#  84  技能20向量    1 non-null      object
#  85  職缺技能向量清單  5 non-null      object
# dtypes: float64(14), int64(3), object(69)
# memory usage: 3.5+ KB

# %%
def recommend_courses_for_job(job_skill_vector_list, course_df, threshold=0.6):

    match_records = []

    for i, course in course_df.iterrows():
        course_skills = course["課程技能向量清單"]
        matched_skills = []

        for job_skill in job_skill_vector_list:
            job_vec = job_skill["向量"]
            job_name = job_skill["技能名"]

            similarities = []
            for course_skill in course_skills:
                sim = cosine_similarity([job_vec], [course_skill["向量"]])[0][0]
                similarities.append(sim)

            if similarities and max(similarities) >= threshold:
                matched_skills.append(
                    {"技能名": job_name, "相似度": round(max(similarities), 3)}
                )

        if matched_skills:
            avg_score = round(np.mean([s["相似度"] for s in matched_skills]), 3)
            match_records.append(
                {
                    "課程名稱": course["課程名稱"],
                    "課程網址": course["課程網址"],
                    "覆蓋技能數": len(matched_skills),
                    "平均相似度": avg_score,
                    "覆蓋技能明細": matched_skills,
                }
            )

    # 所有被覆蓋到的技能
    covered_skills = set()
    for rec in match_records:
        covered_skills.update(skill["技能名"] for skill in rec["覆蓋技能明細"])

    # 所有職缺技能
    job_required_skills = set(skill["技能名"] for skill in job_skill_vector_list)

    # 判斷缺口
    uncovered_skills = list(job_required_skills - covered_skills)
    is_fully_covered = len(uncovered_skills) == 0

    # 根據 覆蓋技能數 → 平均相似度 排序課程
    match_records_sorted = sorted(
        match_records, key=lambda r: (-r["覆蓋技能數"], -r["平均相似度"])
    )

    return {
        "是否全技能被涵蓋": is_fully_covered,
        "職缺技能總數": len(job_required_skills),
        "實際被涵蓋數": len(covered_skills),
        "未被覆蓋技能": uncovered_skills,
        "推薦課程數": len(match_records_sorted),
        "推薦課程清單": match_records_sorted,
    }


def parse_vector_field(raw_field):
    if isinstance(raw_field, str):
        try:
            return ast.literal_eval(raw_field)
        except Exception as e:
            print("⚠️ 向量解析錯誤：", e)
            return []
    elif isinstance(raw_field, list):
        return raw_field
    else:
        return []

# %%
job_df["職缺技能向量清單"] = job_df["職缺技能向量清單"].apply(parse_vector_field)
course_df["課程技能向量清單"] = course_df["課程技能向量清單"].apply(parse_vector_field)

# %%
job_df.info()
job_df["職缺連結"]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 86 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   job_id    5 non-null      object
#  1   更新日期      5 non-null      object
#  2   查詢職類      5 non-null      int64
#  3   查詢關鍵字     5 non-null      object
#  4   職務類別      5 non-null      object
#  5   職缺名稱      5 non-null      object
#  6   公司名稱      5 non-null      object
#  7   公司連結      5 non-null      object
#  8   產業別       5 non-null      object
#  9   上班地點      5 non-null      object
#  10  地區        5 non-null      object
#  11  城市        5 non-null      object
#  12  國家        5 non-null      object
#  13  薪資        5 non-null      object
#  14  薪資下限      5 non-null      int64
#  15  薪資上限      5 non-null      int64
#  16  職缺描述      5 non-null      object
#  17  職務需求      0 non-null      float64
#  18  工作經歷要求    5 non-null      object
#  19  學歷要求      5 non-null      object
#  20  科系要求      1 non-null      object
#  21  擅長工具      4 non-null      object
#  22  中文聽力      0 non-null      float64
#  23  中文口說      0 non-null      float64
#  24  中文閱讀      0 non-null      float64
#  25  中文寫作      0 non-null      float64
#  26  英文聽力      1 non-null      object
#  27  英文口說      1 non-null      object
#  28  英文閱讀      1 non-null      object
#  29  英文寫作      1 non-null      object
#  30  日文聽力      0 non-null      float64
#  31  日文口說      0 non-null      float64
#  32  日文閱讀      0 non-null      float64
#  33  日文寫作      0 non-null      float64
#  34  台語聽力      0 non-null      float64
#  35  台語口說      0 non-null      float64
#  36  台語閱讀      0 non-null      float64
#  37  台語寫作      0 non-null      float64
#  38  其他條件      1 non-null      object
#  39  福利制度      4 non-null      object
#  40  法定福利      3 non-null      object
#  41  其他福利      5 non-null      object
#  42  面試流程      0 non-null      float64
#  43  職缺連結      5 non-null      object
#  44  爬取時間      5 non-null      object
#  45  技能1       5 non-null      object
#  46  技能2       5 non-null      object
#  47  技能3       5 non-null      object
#  48  技能4       5 non-null      object
#  49  技能5       5 non-null      object
#  50  技能6       5 non-null      object
#  51  技能7       5 non-null      object
#  52  技能8       5 non-null      object
#  53  技能9       5 non-null      object
#  54  技能10      5 non-null      object
#  55  技能11      3 non-null      object
#  56  技能12      3 non-null      object
#  57  技能13      2 non-null      object
#  58  技能14      2 non-null      object
#  59  技能15      1 non-null      object
#  60  技能16      1 non-null      object
#  61  技能17      1 non-null      object
#  62  技能18      1 non-null      object
#  63  技能19      1 non-null      object
#  64  技能20      1 non-null      object
#  65  技能1向量     5 non-null      object
#  66  技能2向量     5 non-null      object
#  67  技能3向量     5 non-null      object
#  68  技能4向量     5 non-null      object
#  69  技能5向量     5 non-null      object
#  70  技能6向量     5 non-null      object
#  71  技能7向量     5 non-null      object
#  72  技能8向量     5 non-null      object
#  73  技能9向量     5 non-null      object
#  74  技能10向量    5 non-null      object
#  75  技能11向量    3 non-null      object
#  76  技能12向量    3 non-null      object
#  77  技能13向量    2 non-null      object
#  78  技能14向量    2 non-null      object
#  79  技能15向量    1 non-null      object
#  80  技能16向量    1 non-null      object
#  81  技能17向量    1 non-null      object
#  82  技能18向量    1 non-null      object
#  83  技能19向量    1 non-null      object
#  84  技能20向量    1 non-null      object
#  85  職缺技能向量清單  5 non-null      object
# dtypes: float64(14), int64(3), object(69)
# memory usage: 3.5+ KB
# 0    https://www.104.com.tw/job/8f54d
# 1    https://www.104.com.tw/job/7p2cn
# 2    https://www.104.com.tw/job/8cbyv
# 3    https://www.104.com.tw/job/8b902
# 4    https://www.104.com.tw/job/8bz2q
# Name: 職缺連結, dtype: object

# %%
job = job_df.iloc[2]
job_vector_list = job["職缺技能向量清單"]

# job_vector_list
result = recommend_courses_for_job(job_vector_list, course_df)
pp(result)
# Out:
# {'實際被涵蓋數': 11,
#  '推薦課程數': 26,
#  '推薦課程清單': [{'平均相似度': np.float64(0.649),
#              '覆蓋技能數': 6,
#              '覆蓋技能明細': [{'技能名': 'Node.js（Node.js）: 熟悉後端服務開發，負責 Backend '
#                                 '程式設計與擬定開發計畫',
#                          '相似度': np.float64(0.702)},
#                         {'技能名': ' 管理快取與訊息佇列  \n'
#                                 'Docker（Docker）: 容器化部署，建立一致的開發與運行環境',
#                          '相似度': np.float64(0.609)},
#                         {'技能名': ' 進行服務容器化與持續部署  \n'
#                                 'Distributed Services（分散式服務架構）: 設計與實作微服務架構',
#                          '相似度': np.float64(0.614)},
#                         {'技能名': ' 進行網路相關問題排查與優化  \n'
#                                 'DevOps工具與流程（DevOps Tools & Processes）: '
#                                 '持續整合(CI)、持續部署(CD)、自動化測試與監控',
#                          '相似度': np.float64(0.602)},
#                         {'技能名': ' 使用雲端服務（AWS, GCP, Digital Ocean）進行服務部署與管理  \n'
#                                 '系統監控（System Monitoring）: 監控服務運行狀態與性能',
#                          '相似度': np.float64(0.7)},
#                         {'技能名': ' 進行系統分析與設計  \n'
#                                 '軟體程式設計（Software Programming）: 編寫與維護後端程式碼',
#                          '相似度': np.float64(0.666)}],
#              '課程名稱': 'IBM Full Stack Software Developer',
#              '課程網址': 'https://www.coursera.org/professional-certificates/ibm-full-stack-cloud-developer'},
#             {'平均相似度': np.float64(0.643),
#              '覆蓋技能數': 4,
#              '覆蓋技能明細': [{'技能名': 'Node.js（Node.js）: 熟悉後端服務開發，負責 Backend '
#                                 '程式設計與擬定開發計畫',
#                          '相似度': np.float64(0.652)},
#                         {'技能名': ' 進行服務部署與優化  \n'
#                                 'Javascript ES6（JavaScript ES6）: '
#                                 '編寫高效、可維護的後端程式碼',
#                          '相似度': np.float64(0.624)},
#                         {'技能名': ' 進行網路相關問題排查與優化  \n'
#                                 'DevOps工具與流程（DevOps Tools & Processes）: '
#                                 '持續整合(CI)、持續部署(CD)、自動化測試與監控',
#                          '相似度': np.float64(0.691)},
#                         {'技能名': ' 進行系統分析與設計  \n'
#                                 '軟體程式設計（Software Programming）: 編寫與維護後端程式碼',
#                          '相似度': np.float64(0.606)}],
#              '課程名稱': 'Code Faster with Tabnine: Optimise a NextJS Application',
#              '課程網址': 'https://www.coursera.org/projects/rudi-hinds-ai-code-faster-with-tabnine-optimise-a-nextjs-application'},
#             {'平均相似度': np.float64(0.642),
#              '覆蓋技能數': 4,
#              '覆蓋技能明細': [{'技能名': 'Node.js（Node.js）: 熟悉後端服務開發，負責 Backend '
#                                 '程式設計與擬定開發計畫',
#                          '相似度': np.float64(0.704)},
#                         {'技能名': ' 參與分散式服務設計與實作', '相似度': np.float64(0.606)},
#                         {'技能名': ' 進行服務部署與優化  \n'
#                                 'Javascript ES6（JavaScript ES6）: '
#                                 '編寫高效、可維護的後端程式碼',
#                          '相似度': np.float64(0.654)},
#                         {'技能名': ' 進行網路相關問題排查與優化  \n'
#                                 'DevOps工具與流程（DevOps Tools & Processes）: '
#                                 '持續整合(CI)、持續部署(CD)、自動化測試與監控',
#                          '相似度': np.float64(0.602)}],
#              '課程名稱': 'React Basics',
#              '課程網址': 'https://www.coursera.org/learn/react-basics'},
#             {'平均相似度': np.float64(0.641),
#              '覆蓋技能數': 4,
#              '覆蓋技能明細': [{'技能名': ' 進行網路相關問題排查與優化  \n'
#                                 'DevOps工具與流程（DevOps Tools & Processes）: '
#                                 '持續整合(CI)、持續部署(CD)、自動化測試與監控',
#                          '相似度': np.float64(0.621)},
#                         {'技能名': ' 進行故障排除與性能優化  \n'
#                                 '軟體工程系統開發（Software System Development）: '
#                                 '軟體架構設計與系統整合',
#                          '相似度': np.float64(0.643)},
#                         {'技能名': ' 進行系統分析與設計  \n'
#                                 '軟體程式設計（Software Programming）: 編寫與維護後端程式碼',
#                          '相似度': np.float64(0.636)},
#                         {'技能名': ' 進行模組化與重構  \n'
#                                 '網路程式設計（Network Programming）: 開發與優化網路相關功能',
#                          '相似度': np.float64(0.665)}],
#              '課程名稱': 'Excel/VBA for Creative Problem Solving, Part 3 '
#                      '(Projects)',
#              '課程網址': 'https://www.coursera.org/learn/excel-vba-for-creative-problem-solving-part-3-projects'},
#             {'平均相似度': np.float64(0.613),
#              '覆蓋技能數': 4,
#              '覆蓋技能明細': [{'技能名': ' 進行網路相關問題排查與優化  \n'
#                                 'DevOps工具與流程（DevOps Tools & Processes）: '
#                                 '持續整合(CI)、持續部署(CD)、自動化測試與監控',
#                          '相似度': np.float64(0.604)},
#                         {'技能名': ' 使用雲端服務（AWS, GCP, Digital Ocean）進行服務部署與管理  \n'
#                                 '系統監控（System Monitoring）: 監控服務運行狀態與性能',
#                          '相似度': np.float64(0.626)},
#                         {'技能名': ' 進行故障排除與性能優化  \n'
#                                 '軟體工程系統開發（Software System Development）: '
#                                 '軟體架構設計與系統整合',
#                          '相似度': np.float64(0.606)},
#                         {'技能名': ' 進行模組化與重構  \n'
#                                 '網路程式設計（Network Programming）: 開發與優化網路相關功能',
#                          '相似度': np.float64(0.615)}],
#              '課程名稱': 'Java Enterprise Edition',
#              '課程網址': 'https://www.coursera.org/specializations/java-ee'},
#             {'平均相似度': np.float64(0.722),
#              '覆蓋技能數': 3,
#              '覆蓋技能明細': [{'技能名': ' 服務間的通信與協調  \n'
#                                 '網路協定（HTTP, HTTPS, WebSocket, TCP/IP）: '
#                                 '理解網路層級協定，確保服務安全性與穩定性',
#                          '相似度': np.float64(0.728)},
#                         {'技能名': ' 進行網路相關問題排查與優化  \n'
#                                 'DevOps工具與流程（DevOps Tools & Processes）: '
#                                 '持續整合(CI)、持續部署(CD)、自動化測試與監控',
#                          '相似度': np.float64(0.769)},
#                         {'技能名': ' 使用雲端服務（AWS, GCP, Digital Ocean）進行服務部署與管理  \n'
#                                 '系統監控（System Monitoring）: 監控服務運行狀態與性能',
#                          '相似度': np.float64(0.67)}],
#              '課程名稱': 'Introduction to Security Principles in Cloud Computing',
#              '課程網址': 'https://www.coursera.org/learn/introduction-to-security-principles-in-cloud-computing'},
#             {'平均相似度': np.float64(0.704),
#              '覆蓋技能數': 3,
#              '覆蓋技能明細': [{'技能名': ' 進行服務容器化與持續部署  \n'
#                                 'Distributed Services（分散式服務架構）: 設計與實作微服務架構',
#                          '相似度': np.float64(0.651)},
#                         {'技能名': ' 進行網路相關問題排查與優化  \n'
#                                 'DevOps工具與流程（DevOps Tools & Processes）: '
#                                 '持續整合(CI)、持續部署(CD)、自動化測試與監控',
#                          '相似度': np.float64(0.805)},
#                         {'技能名': ' 使用雲端服務（AWS, GCP, Digital Ocean）進行服務部署與管理  \n'
#                                 '系統監控（System Monitoring）: 監控服務運行狀態與性能',
#                          '相似度': np.float64(0.657)}],
#              '課程名稱': 'GenAI for Application Developers',
#              '課程網址': 'https://www.coursera.org/learn/genai-for-application-developers'},
#             {'平均相似度': np.float64(0.696),
#              '覆蓋技能數': 3,
#              '覆蓋技能明細': [{'技能名': ' 服務間的通信與協調  \n'
#                                 '網路協定（HTTP, HTTPS, WebSocket, TCP/IP）: '
#                                 '理解網路層級協定，確保服務安全性與穩定性',
#                          '相似度': np.float64(0.776)},
#                         {'技能名': ' 進行網路相關問題排查與優化  \n'
#                                 'DevOps工具與流程（DevOps Tools & Processes）: '
#                                 '持續整合(CI)、持續部署(CD)、自動化測試與監控',
#                          '相似度': np.float64(0.621)},
#                         {'技能名': ' 進行模組化與重構  \n'
#                                 '網路程式設計（Network Programming）: 開發與優化網路相關功能',
#                          '相似度': np.float64(0.691)}],
#              '課程名稱': 'Network Implementations and Operations',
#              '課程網址': 'https://www.coursera.org/learn/packt-network-implementations-and-operations-prgbo'},
#             {'平均相似度': np.float64(0.627),
#              '覆蓋技能數': 3,
#              '覆蓋技能明細': [{'技能名': ' 進行網路相關問題排查與優化  \n'
#                                 'DevOps工具與流程（DevOps Tools & Processes）: '
#                                 '持續整合(CI)、持續部署(CD)、自動化測試與監控',
#                          '相似度': np.float64(0.609)},
#                         {'技能名': ' 使用雲端服務（AWS, GCP, Digital Ocean）進行服務部署與管理  \n'
#                                 '系統監控（System Monitoring）: 監控服務運行狀態與性能',
#                          '相似度': np.float64(0.655)},
#                         {'技能名': ' 進行故障排除與性能優化  \n'
#                                 '軟體工程系統開發（Software System Development）: '
#                                 '軟體架構設計與系統整合',
#                          '相似度': np.float64(0.616)}],
#              '課程名稱': 'Machine Learning Implementation and Operations in AWS',
#              '課程網址': 'https://www.coursera.org/learn/machine-learning-implementation-and-operations-in-aws'},
#             {'平均相似度': np.float64(0.657),
#              '覆蓋技能數': 2,
#              '覆蓋技能明細': [{'技能名': ' 進行故障排除與性能優化  \n'
#                                 '軟體工程系統開發（Software System Development）: '
#                                 '軟體架構設計與系統整合',
#                          '相似度': np.float64(0.651)},
#                         {'技能名': ' 進行系統分析與設計  \n'
#                                 '軟體程式設計（Software Programming）: 編寫與維護後端程式碼',
#                          '相似度': np.float64(0.662)}],
#              '課程名稱': 'GenAI for Telemedicine Data Security',
#              '課程網址': 'https://www.coursera.org/learn/genai-for-telemedicine-data-security'},
#             {'平均相似度': np.float64(0.637),
#              '覆蓋技能數': 2,
#              '覆蓋技能明細': [{'技能名': ' 進行網路相關問題排查與優化  \n'
#                                 'DevOps工具與流程（DevOps Tools & Processes）: '
#                                 '持續整合(CI)、持續部署(CD)、自動化測試與監控',
#                          '相似度': np.float64(0.606)},
#                         {'技能名': ' 進行模組化與重構  \n'
#                                 '網路程式設計（Network Programming）: 開發與優化網路相關功能',
#                          '相似度': np.float64(0.668)}],
#              '課程名稱': 'Introduction to Technology-Assisted Decision-Making',
#              '課程網址': 'https://www.coursera.org/learn/introduction-to-technology-assisted-decision-making'},
#             {'平均相似度': np.float64(0.617),
#              '覆蓋技能數': 2,
#              '覆蓋技能明細': [{'技能名': ' 進行網路相關問題排查與優化  \n'
#                                 'DevOps工具與流程（DevOps Tools & Processes）: '
#                                 '持續整合(CI)、持續部署(CD)、自動化測試與監控',
#                          '相似度': np.float64(0.633)},
#                         {'技能名': ' 使用雲端服務（AWS, GCP, Digital Ocean）進行服務部署與管理  \n'
#                                 '系統監控（System Monitoring）: 監控服務運行狀態與性能',
#                          '相似度': np.float64(0.602)}],
#              '課程名稱': 'BigQuery 머신러닝을 사용한 추론',
#              '課程網址': 'https://www.coursera.org/learn/bigquery-ko'},
#             {'平均相似度': np.float64(0.612),
#              '覆蓋技能數': 2,
#              '覆蓋技能明細': [{'技能名': ' 進行網路相關問題排查與優化  \n'
#                                 'DevOps工具與流程（DevOps Tools & Processes）: '
#                                 '持續整合(CI)、持續部署(CD)、自動化測試與監控',
#                          '相似度': np.float64(0.604)},
#                         {'技能名': ' 使用雲端服務（AWS, GCP, Digital Ocean）進行服務部署與管理  \n'
#                                 '系統監控（System Monitoring）: 監控服務運行狀態與性能',
#                          '相似度': np.float64(0.62)}],
#              '課程名稱': 'AWS AI Practitioner',
#              '課程網址': 'https://www.coursera.org/specializations/aws-certified-ai-practitioner'},
#             {'平均相似度': np.float64(0.719),
#              '覆蓋技能數': 1,
#              '覆蓋技能明細': [{'技能名': ' 服務間的通信與協調  \n'
#                                 '網路協定（HTTP, HTTPS, WebSocket, TCP/IP）: '
#                                 '理解網路層級協定，確保服務安全性與穩定性',
#                          '相似度': np.float64(0.719)}],
#              '課程名稱': 'Cryptography',
#              '課程網址': 'https://www.coursera.org/learn/cryptography'},
#             {'平均相似度': np.float64(0.664),
#              '覆蓋技能數': 1,
#              '覆蓋技能明細': [{'技能名': ' 進行系統分析與設計  \n'
#                                 '軟體程式設計（Software Programming）: 編寫與維護後端程式碼',
#                          '相似度': np.float64(0.664)}],
#              '課程名稱': 'Computer Science: Programming with a Purpose',
#              '課程網址': 'https://www.coursera.org/learn/cs-programming-java'},
#             {'平均相似度': np.float64(0.643),
#              '覆蓋技能數': 1,
#              '覆蓋技能明細': [{'技能名': ' 進行網路相關問題排查與優化  \n'
#                                 'DevOps工具與流程（DevOps Tools & Processes）: '
#                                 '持續整合(CI)、持續部署(CD)、自動化測試與監控',
#                          '相似度': np.float64(0.643)}],
#              '課程名稱': 'Planning for your Google Workspace Deployment 日本語版',
#              '課程網址': 'https://www.coursera.org/learn/deploying-g-suite-jp'},
#             {'平均相似度': np.float64(0.637),
#              '覆蓋技能數': 1,
#              '覆蓋技能明細': [{'技能名': ' 使用雲端服務（AWS, GCP, Digital Ocean）進行服務部署與管理  \n'
#                                 '系統監控（System Monitoring）: 監控服務運行狀態與性能',
#                          '相似度': np.float64(0.637)}],
#              '課程名稱': 'Introduction to Large Language Models - Bahasa Indonesia',
#              '課程網址': 'https://www.coursera.org/learn/introduction-to-large-language-models---bahasa-indonesia'},
#             {'平均相似度': np.float64(0.633),
#              '覆蓋技能數': 1,
#              '覆蓋技能明細': [{'技能名': ' 進行網路相關問題排查與優化  \n'
#                                 'DevOps工具與流程（DevOps Tools & Processes）: '
#                                 '持續整合(CI)、持續部署(CD)、自動化測試與監控',
#                          '相似度': np.float64(0.633)}],
#              '課程名稱': 'Strategic Info Systems: Planning & Business Alignment',
#              '課程網址': 'https://www.coursera.org/learn/strategic-info-systems-planning--business-alignment'},
#             {'平均相似度': np.float64(0.631),
#              '覆蓋技能數': 1,
#              '覆蓋技能明細': [{'技能名': ' 進行系統分析與設計  \n'
#                                 '軟體程式設計（Software Programming）: 編寫與維護後端程式碼',
#                          '相似度': np.float64(0.631)}],
#              '課程名稱': 'Advanced Data Structures and Algorithms',
#              '課程網址': 'https://www.coursera.org/learn/packt-advanced-data-structures-and-algorithms-bsgud'},
#             {'平均相似度': np.float64(0.628),
#              '覆蓋技能數': 1,
#              '覆蓋技能明細': [{'技能名': ' 進行故障排除與性能優化  \n'
#                                 '軟體工程系統開發（Software System Development）: '
#                                 '軟體架構設計與系統整合',
#                          '相似度': np.float64(0.628)}],
#              '課程名稱': 'IBM Data Warehouse Engineer',
#              '課程網址': 'https://www.coursera.org/professional-certificates/data-warehouse-engineering'},
#             {'平均相似度': np.float64(0.628),
#              '覆蓋技能數': 1,
#              '覆蓋技能明細': [{'技能名': ' 參與分散式服務設計與實作', '相似度': np.float64(0.628)}],
#              '課程名稱': 'PySpark for Data Science',
#              '課程網址': 'https://www.coursera.org/specializations/pyspark-for-data-science'},
#             {'平均相似度': np.float64(0.621),
#              '覆蓋技能數': 1,
#              '覆蓋技能明細': [{'技能名': ' 進行網路相關問題排查與優化  \n'
#                                 'DevOps工具與流程（DevOps Tools & Processes）: '
#                                 '持續整合(CI)、持續部署(CD)、自動化測試與監控',
#                          '相似度': np.float64(0.621)}],
#              '課程名稱': 'Test Driven Development in Java for Beginners',
#              '課程網址': 'https://www.coursera.org/projects/test-driven-development-in-java'},
#             {'平均相似度': np.float64(0.62),
#              '覆蓋技能數': 1,
#              '覆蓋技能明細': [{'技能名': ' 參與分散式服務設計與實作', '相似度': np.float64(0.62)}],
#              '課程名稱': 'Strategic Technology Management',
#              '課程網址': 'https://www.coursera.org/specializations/technology-management'},
#             {'平均相似度': np.float64(0.618),
#              '覆蓋技能數': 1,
#              '覆蓋技能明細': [{'技能名': ' 進行故障排除與性能優化  \n'
#                                 '軟體工程系統開發（Software System Development）: '
#                                 '軟體架構設計與系統整合',
#                          '相似度': np.float64(0.618)}],
#              '課程名稱': 'Inventory Management',
#              '課程網址': 'https://www.coursera.org/learn/inventory-management-in-tally'},
#             {'平均相似度': np.float64(0.613),
#              '覆蓋技能數': 1,
#              '覆蓋技能明細': [{'技能名': ' 使用雲端服務（AWS, GCP, Digital Ocean）進行服務部署與管理  \n'
#                                 '系統監控（System Monitoring）: 監控服務運行狀態與性能',
#                          '相似度': np.float64(0.613)}],
#              '課程名稱': 'Enabling Sensitive Data Protection Discovery for '
#                      'BigQuery',
#              '課程網址': 'https://www.coursera.org/projects/googlecloud-enabling-sensitive-data-protection-discovery-for-bigquery-yu1ce'},
#             {'平均相似度': np.float64(0.608),
#              '覆蓋技能數': 1,
#              '覆蓋技能明細': [{'技能名': ' 進行網路相關問題排查與優化  \n'
#                                 'DevOps工具與流程（DevOps Tools & Processes）: '
#                                 '持續整合(CI)、持續部署(CD)、自動化測試與監控',
#                          '相似度': np.float64(0.608)}],
#              '課程名稱': 'Responsible AI for Developers: Interpretability & '
#                      'Transparency - Italiano',
#              '課程網址': 'https://www.coursera.org/learn/responsible-ai-for-developers-interpretability-transparency-it'}],
#  '是否全技能被涵蓋': False,
#  '未被覆蓋技能': [' 進行網路協定的應用與調試  \n資料庫程式設計（Database Programming）: 資料庫',
#             ' 使用現代語法提升開發效率與程式品質  \n'
#             'TypeScript（TypeScript）: 強化型別檢查，提升大型專案的可維護性與可靠性  \n'
#             'MongoDB（MongoDB）: 資料庫設計與操作，資料存取與管理',
#             ' 儲存與查詢非關聯性資料  \nRedis（Redis）: 快取系統設計與實作，提升資料存取速度'],
#  '職缺技能總數': 14}
